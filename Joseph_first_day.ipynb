# %% [markdown]
# <a href="https://colab.research.google.com/github/darlingdaniel4790/warning-designs-survey/blob/main/Joseph_first_day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: create a variable name

variable_name = "my_variable"

# %%
# prompt: write a hello world code

print("hello world")
# Out:
# hello world
